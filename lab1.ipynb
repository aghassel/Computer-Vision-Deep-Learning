# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/My Drive/Colab Notebooks/ELEC475/Lab1"
# Out:
# data  main.py  MLP.8.pth  model.py  __pycache__  test.ipynb  train.py

# %%
# !python train.py -z 8 -e 50 -b 2048 -s MLP.8.pth -p loss.MLP.8.png
# Out:
# ...
# 100% 9912422/9912422 [00:00<00:00, 296437895.23it/s]
# Extracting ./data/mnist/MNIST/raw/train-images-idx3-ubyte.gz to ./data/mnist/MNIST/raw
#
# ...
# 100% 28881/28881 [00:00<00:00, 141348534.22it/s]
# Extracting ./data/mnist/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/mnist/MNIST/raw
#
# ...
# 100% 1648877/1648877 [00:00<00:00, 81219144.77it/s]
# Extracting ./data/mnist/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/mnist/MNIST/raw
#
# ...
# 100% 4542/4542 [00:00<00:00, 26385773.92it/s]
# Extracting ./data/mnist/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/mnist/MNIST/raw
#
# training...
# epoch  1
# ...

# %%
# %run lab1.py
